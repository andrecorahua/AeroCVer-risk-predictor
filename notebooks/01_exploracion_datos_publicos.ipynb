# %% [markdown]
# # 01. Exploración de Datos Públicos - AeroSafe Risk Predictor
#
# **Objetivo:** Realizar el Análisis Exploratorio de Datos (EDA) de un dataset público de aviación (NTSB/FAA) para identificar variables clave de riesgo.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Configuración de visualización
# %matplotlib inline
sns.set(style="whitegrid")

# %% [markdown]
# ## 1. Carga de Datos
# Cargaremos el dataset descargado en la carpeta `data/raw/`.

# %%
# Ruta al dataset (ajustar nombre del archivo cuando lo descargues)
data_path = "../data/raw/aviation_data.csv"

if os.path.exists(data_path):
    df = pd.read_csv(data_path)
    print("Dataset cargado exitosamente.")
    display(df.head())
else:
    print("Archivo no encontrado. Por favor, descarga el CSV en data/raw/")
